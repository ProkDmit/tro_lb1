# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f1 = f2 = 1
amount = int(input())
# Out:
# 8

# %%
print(f1, f2, end=' ')
for i in range(2, amount):
    f1, f2 = f2, f1 + f2
    print(f2, end=' ')
# Out:
# 1 1 2 3 5 8 13 21
